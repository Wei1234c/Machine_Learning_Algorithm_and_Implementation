# %% [markdown]
# # convert 2 to 3

# %%
import os 

for dirPath, dirNames, fileNames in os.walk("."):
    print(dirPath)
    for f in fileNames: 
        
        file_name = os.path.join(dirPath, f)
        print(file_name)
        if file_name.endswith('.py'):
            !2to3 -w {file_name}
# Out:
# .
# .\convert 2 to 3.ipynb
# .\.ipynb_checkpoints
# .\chapter01
# .\chapter01\base1.py
# --- .\chapter01\base1.py	(original)
# +++ .\chapter01\base1.py	(refactored)
# @@ -4,12 +4,13 @@
#  import os
#  from numpy import *
#  import matplotlib.pyplot as plt
# +import imp
# .\chapter01\base2.py
# RefactoringTool: Skipping optional fixer: buffer
# RefactoringTool: Skipping optional fixer: idioms
# RefactoringTool: Skipping optional fixer: set_literal
# RefactoringTool: Skipping optional fixer: ws_comma
# RefactoringTool: Refactored .\chapter01\base1.py
# WARNING: couldn't encode .\chapter01\base1.py's diff for your terminal
# RefactoringTool: Files that were modified:
# RefactoringTool: .\chapter01\base1.py
# --- .\chapter01\base2.py	(original)
# +++ .\chapter01\base2.py	(refactored)
# @@ -4,17 +4,18 @@
#  import os
#  from numpy import *
#  import matplotlib.pyplot as plt
# +import imp
# .\chapter01\distance1.py
# RefactoringTool: Skipping optional fixer: buffer
# ...
